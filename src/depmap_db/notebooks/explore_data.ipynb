# %%
import pandas as pd

df = pd.read_csv("/Users/hh65/depmap_data/combined_model_crispr_data.csv")
df.head()
# Out:
#      model_id cell_line_name stripped_cell_line_name      oncotree_lineage  \
# 0  ACH-000001    NIH:OVCAR-3               NIHOVCAR3  Ovary/Fallopian Tube
# 1  ACH-000004            HEL                     HEL               Myeloid
# 2  ACH-000005     HEL 92.1.7                 HEL9217               Myeloid
# 3  ACH-000007          LS513                   LS513                 Bowel
# 4  ACH-000009         C2BBe1                  C2BBE1                 Bowel
#
#     oncotree_primary_disease                  oncotree_subtype      A1BG  \
# 0   Ovarian Epithelial Tumor  High-Grade Serous Ovarian Cancer -0.111951
# 1     Acute Myeloid Leukemia                          AML, NOS  0.005506
# 2     Acute Myeloid Leukemia            Acute Myeloid Leukemia -0.112103
# 3  Colorectal Adenocarcinoma              Colon Adenocarcinoma -0.042371
# 4  Colorectal Adenocarcinoma              Colon Adenocarcinoma  0.036096
#
# ...

# %%
df.oncotree_lineage.unique()
# Out:
# array(['Ovary/Fallopian Tube', 'Myeloid', 'Bowel',
#        'Bladder/Urinary Tract', 'Lung', 'Skin', 'Breast', 'Pancreas',
#        'Lymphoid', 'CNS/Brain', 'Soft Tissue', 'Bone',
#        'Esophagus/Stomach', 'Peripheral Nervous System', 'Pleura',
#        'Prostate', 'Kidney', 'Fibroblast', 'Biliary Tract',
#        'Head and Neck', 'Thyroid', 'Ampulla of Vater', 'Uterus', 'Liver',
#        'Cervix', 'Eye', 'Vulva/Vagina', 'Adrenal Gland', 'Testis',
#        'Other'], dtype=object)

# %%
df1 = df[df["oncotree_lineage"].isin(["Breast", "Myeloid"])]
print(df1.head())
print(df1.shape)
df1.to_csv(
    "/Users/hh65/depmap_data/combined_model_crispr_data_filtered.csv",
    index=False,
)
# Out:
#       model_id cell_line_name stripped_cell_line_name oncotree_lineage  \
# 1   ACH-000004            HEL                     HEL          Myeloid
# 2   ACH-000005     HEL 92.1.7                 HEL9217          Myeloid
# 10  ACH-000017        SK-BR-3                   SKBR3           Breast
# 12  ACH-000019           MCF7                    MCF7           Breast
# 19  ACH-000028          KPL-1                    KPL1           Breast
#
#      oncotree_primary_disease           oncotree_subtype      A1BG      A1CF  \
# 1      Acute Myeloid Leukemia                   AML, NOS  0.005506 -0.069734
# 2      Acute Myeloid Leukemia     Acute Myeloid Leukemia -0.112103  0.008739
# 10  Invasive Breast Carcinoma  Invasive Breast Carcinoma -0.032172 -0.102181
# 12  Invasive Breast Carcinoma  Invasive Breast Carcinoma  0.036307  0.018542
# 19  Invasive Breast Carcinoma  Invasive Breast Carcinoma -0.187719 -0.149819
#
# ...

# %%
df1.groupby("oncotree_lineage")["A1BG"].count()
# Out:
# oncotree_lineage
# Breast     53
# Myeloid    41
# Name: A1BG, dtype: int64

# %%
import ssl

# %%
# Python 3.13 specific SSL context
ssl_context = ssl.create_default_context()
ssl_context.check_hostname = True
ssl_context.verify_mode = ssl.CERT_REQUIRED

# Load system certificates explicitly
ssl_context.load_default_certs(ssl.Purpose.SERVER_AUTH)

# %%
df2 = pd.read_csv(
    "https://zenodo.org/records/16636600/files/sample_plate_data.csv?download=1"
)
# Out:
# ---------------------------------------------------------------------------
# SSLCertVerificationError                  Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/urllib/request.py:1319, in AbstractHTTPHandler.do_open(self, http_class, req, **http_conn_args)
#    1318 try:
# -> 1319     h.request(req.get_method(), req.selector, req.data, headers,
#    1320               encode_chunked=req.has_header('Transfer-encoding'))
#    1321 except OSError as err: # timeout error
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/http/client.py:1338, in HTTPConnection.request(self, method, url, body, headers, encode_chunked)
#    1337 """Send a complete request to the server."""
# -> 1338 self._send_request(method, url, body, headers, encode_chunked)
#
# ...
